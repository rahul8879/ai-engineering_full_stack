# %%
salary = '1200'
type(salary)

isData_available = True
type(isData_available)
# Out:
# bool

# %%
num_1 = 12
num_2 = "3.14"
# operation
num_1 + num_2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       1 num_1 = 12
#       2 num_2 = "3.14"
#       3 # operation
# ----> 4 num_1 + num_2
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
salary = 1200
float(salary) # type casting # int --> float
# Out:
# 1200.0

# %%
sales = 12.75
str(sales)
# Out:
# '12.75'

# %%
sales = '12.75'
new_sales = float(sales)
type(new_sales)
# Out:
# float

# %%
num_1 = 12
num_2 = "3.14"
# operation
num_1 + float(num_2)
# Out:
# 15.14

# %%
id(num_1)
# Out:
# 4356467480

# %%
id(num_2)
# Out:
# 4409816480

# %%
a = [17,89,76]

b = a

# %%
b
# Out:
# [17, 89, 76]

# %%
id(a)
# Out:
# 4410457664

# %%
id(b)
# Out:
# 4410457664

# %%
b[2] = 100
b
# Out:
# [17, 89, 100]

# %%
a
# Out:
# [17, 89, 100]

# %%
salary = 1200

# 2_salary = 12000

# rules for declaring the variable
# 1. Variable names must start with a letter or underscore (_), 
# followed by letters, numbers, or underscores.
# 2. Variable names cannot be a reserved keyword in Python.

test_2_something = 1200

# import keyword
# keyword.kwlist

# %%
ssn_number = input("Enter your SSN number: ")

if len(ssn_number) == 9:
    print("Valid SSN number")
else:
    print("Invalid SSN number")
# Out:
# Valid SSN number

# %%
ssn_number
# Out:
# '3123131312312312'

# %%
num_1 = int(input("Enter num_1: "))
num_2 = int(input("Enter num_2: "))
result = num_1 + num_2
result
# Out:
# 24

# %%
name = 'rbyte.ai'
len(name)
# Out:
# 8

# %%
name[0:5]
# Out:
# 'rbyte'

# %%
# int , float, str, bool, list,tuple, 

marks = [85, 90, 78, 92, 88]
type(marks)

marks [0] = 95
marks
# Out:
# [95, 90, 78, 92, 88]

# %%
marks = (85, 90, 78, 92, 88)
type(marks)
marks[0] = 96
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 3
#       1 marks = (85, 90, 78, 92, 88)
#       2 type(marks)
# ----> 3 marks[0] = 96
#
# TypeError: 'tuple' object does not support item assignment

# %%
def exam_result():
    return ('rahul','test','mahesh', 'xyz')

students = exam_result()

# %%
type(students)
# Out:
# tuple

# %%
students[0]= 'Test-2'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 students[0]= 'Test-2'
#
# TypeError: 'tuple' object does not support item assignment

# %%
students
# Out:
# ['Test-2', 'test', 'mahesh', 'xyz']

# %%
marks = [85, 90, 78, 92, 88]


# add more candidates
marks.append(95)
marks
# Out:
# [85, 90, 78, 92, 88, 95]

# %%
12//9
# Out:
# 1

# %%
13%3
# Out:
# 1

# %%
from testing_variable import salary_inc,upcoming_holiday

salary = 1200
rating = 2
incr_value = salary_inc(rating)
new_salary = salary + (salary * incr_value)
print("New salary for rating", rating, "is:", new_salary)
# Out:
# New salary for rating 2 is: 1200

# %%
upcoming_holiday()
# Out:
# '2023-12-25'

# %%
salary = 1200
increment = 0.1
new_salary = round(salary * (1 + increment), 2)
new_salary

# macos/windows --> shift + enter
# Out:
# 1320.0

# %%
def add(a, b):
    return a + b

# Example
result = add(10, 20)
result
# Out:
# 30
