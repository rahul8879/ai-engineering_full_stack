# %%
marks= [25,28,27,28]
key = 28 


for i in range(len(marks)):
    if marks[i] == key:
        print('found the key and key is avaialble at: ',i)
# Out:
# found the key and key is avaialble at:  1
# found the key and key is avaialble at:  3

# %%
len(marks)
# Out:
# 4

# %%
for i in marks:
    if i == key:
        print('found')
# Out:
# found
# found

# %%
sales = [23,26,27,29,31,26]

# ttoal_sales/total_element
total = 0 
# for i in sales:
#     total = total + i

# avg_sales=total

# %%
for i in range(len(sales)):
    total = total + sales[i]
total
avg_sales = total/len(sales)
print('avg sales:',avg_sales)
# Out:
# avg sales: 54.0

# %%
for i in ('test','test2'):
    print(i)
# Out:
# test
# test2

# %%
sales = [[23,25,26],[34,35,36,37],[38,39,40]]

avg_sales = []
for i in sales:
    total = 0
    total_element = len(i)
    for j in i:
        total = total + j
    avg = round(total/total_element,2)
    avg_sales.append(avg)

avg_sales
# Out:
# [24.67, 35.5, 39.0]

# %%
for i in range(len(sales)):
    total = 0
    total_elemenxt = len(sales[i])
    for j in range(len(sales[i])):
        total = total + sales[i][j]
    avg = round(total/total_element,2)
    avg_sales.append(avg)
avg_sales
# Out:
# [24.67, 35.5, 39.0, 24.67, 35.5, 39.0]

# %%
data = ['rahul','rbyte','hachiion','python','full stack ai engineering']
for i in range(len(data)):
    if data[i] == 'python':
        print('found the key and key is avaialble at: ',i)
        break # to break the loop when we found the key
    print('current element is: ',data[i])

print('outside the loop')
# Out:
# current element is:  rahul
# current element is:  rbyte
# current element is:  hachiion
# found the key and key is avaialble at:  3
# outside the loop

# %%
# continue statement
# take the input from user and check if it is even or odd number. If it is even number then print the number and if it is odd number then skip the number and continue with next iteration

input_num = int(input('enter a number: '))
if input_num % 2 == 0:
    print('even number: ',input_num)
else:
    print('odd number: ',input_num)
# Out:
# odd number:  21

# %%
# to check given number is Prime number or not
num = 15

isDivisible = False

i = 2
while i < num:
    if num % i == 0:
        isDivisible = True
        break
    i = i + 1


print('isDivisible: ',isDivisible)
# Out:
# isDivisible:  True

# %%
input_num = input('enter a number: ')

# %%
input_num.split(',')
# Out:
# ['12', '23', '26']

# %%
number = [45]
for i in number:
    if i % 2 == 0:
        continue
    print(i)
# Out:
# 45

# %%
sales_data = [789,239,234,567,890,321,356]

# total odd day sales?? 
total_odd_sales = 0

# %%
if isDivisible:
    print('not a prime number')
else:
    print('prime number')
    if num == 2:
        print('prime number')

# %%
if isDivisible:
    if num == 2:
        if num == 2:
            print('prime number')
elif isDivisible:
    print('not a prime number')
else:
    print('prime number')

# %%
if true:
    print('true')
elif false:
    print('false')
