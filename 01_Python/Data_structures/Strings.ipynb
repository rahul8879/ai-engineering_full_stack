# %% [markdown]
# # Strings

# %% [markdown]
#     A string is a sequence of characters.
#
#     Computers do not deal with characters, they deal with numbers (binary). Even though you may see characters on your screen, internally it is stored and manipulated as a combination of 0's and 1's.
#
#     This conversion of character to a number is called encoding, and the reverse process is decoding. ASCII and Unicode are some of the popular encoding used.
#
#     In Python, string is a sequence of Unicode character.

# %% [markdown]
# For more details about unicode
#
# https://docs.python.org/3.3/howto/unicode.html

# %% [markdown]
# # How to create a string?

# %% [markdown]
# Strings can be created by enclosing characters inside a single quote or double quotes.
#
# Even triple quotes can be used in Python but generally used to represent multiline strings and docstrings.

# %%
name = ' rahul'

for i in name:
    print(i)
# Out:
#
# r
# a
# h
# u
# l

# %%
input_data = """Hi I am working well but     
Somehting is not working"""
input_data
# Out:
# 'Hi I am working well but     \nSomehting is not working'

# %%
data = f"""Hi here is my mob mumnber : {{}} """
data.format({'915209'})
# Out:
# "Hi here is my mob mumnber : {'915209'} "

# %%
prompt =f"""
You are a classifier agent help me to classify the below email:
{{}}"""



prompt.format({"soemthing is not working"})
# Out:
# "\nYou are a classifier agent help me to classify the below email:\n{'soemthing is not working'}"

# %%
'rahul'.upper()
# Out:
# 'RAHUL'

# %%
prompt = "You are a helpful assistant." \
"You will help me with my tasks."

type(prompt)
print(prompt)
# Out:
# You are a helpful assistant.You will help me with my tasks.

# %%
simple_text = ' Hello-World'
simple_text[0:5]  # Hello
simple_text[6:11]  # World
# Out:
# '-Worl'

# %%
simple_text[2:7]
simple_text[0:7:2]
# Out:
# 'HloW'

# %%
result = 'Category: Billing | score,: 12/10 '
# category : Spam
# Score : 9/10
# Brute force 

category = result.split(':')[1].split('|')[0]
score = result.split(':')[2]

category,score
# Out:
# (' Billing ', ' 12/10 ')

# %%
result.split(':')
# Out:
# ['Category', ' spam | score', ' 9/10']

# %%
result.split(':')
# Out:
# ['Category', ' spam | score', ' 9/10']

# %%
simple_text.split('-')
# Out:
# [' Hello', 'World']

# %%
simple_text.split(' ')  # ['Hello', 'World']
# Out:
# ['Hello', 'World']

# %%
# myString = 'Hello'
# '

# print(myString)


myString = "Hello"
print(myString)


myString = '''Hello
sfsdfsdfsdfdsfasda
DASASDASDASD
ASDASASDASDAS
ASDASDASDASDAS

'''
print(myString)
# Out:
# Hello
# Hello
# sfsdfsdfsdfdsfasda
# DASASDASDASD
# ASDASASDASDAS
# ASDASDASDASDAS

# %% [markdown]
# # How to access characters in a string?

# %% [markdown]
# We can access individual characters using indexing and a range of characters using slicing.
#
# Index starts from 0.
#
# Trying to access a character out of index range will raise an IndexError.
#
# The index must be an integer. We can't use float or other types, this will result into TypeError.
#
# Python allows negative indexing for its sequences.

# %%
myString = "Hello"

#print first Character
print(myString[0])

#print last character using negative indexing
print(myString[-1])

#slicing 2nd to 5th character
print(myString[2:5])
# Out:
# H
# o
# llo

# %% [markdown]
# If we try to access index out of the range or use decimal number, we will get errors.

# %%
print(myString[15])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(myString[15])
#
# IndexError: string index out of range

# %%
print(myString[4])
# Out:
# o

# %% [markdown]
# # How to change or delete a string ?

# %% [markdown]
# Strings are immutable. This means that elements of a string cannot be changed once it has been assigned.
#
# We can simply reassign different strings to the same name.

# %%
output = "XYZ is best country"
output[0:3] = "INDIA"  # This will give error as strings are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 2
#       1 output = "XYZ is best country"
# ----> 2 output[0:3] = "INDIA"  # This will give error as strings are immutable
#
# TypeError: 'str' object does not support item assignment

# %%
myString = "Hello"
myString[4] = 's' # strings are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 2
#       1 myString = "Hello"
# ----> 2 myString[4] = 's' # strings are immutable
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# We cannot delete or remove characters from a string. But deleting the string entirely is possible using the keyword       del.

# %%
del myString # delete complete string

# %%
print(myString)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 print(myString)
#
# NameError: name 'myString' is not defined

# %% [markdown]
# # String Operations

# %% [markdown]
# # Concatenation

# %% [markdown]
# Joining of two or more strings into a single one is called concatenation.
#
# The + operator does this in Python. Simply writing two string literals together also concatenates them.
#
# The * operator can be used to repeat the string for a given number of times.

# %%
s1 = "Hello"
s2 = "Satish"

#concatenation of 2 strings
print(s1 + '###'+ s2)

#repeat string n times
# print(s1 * 3)
# Out:
# Hello###Satish

# %% [markdown]
# # Iterating Through String

# %%
text = 'hellO world'
# count o??
count = 0
for i in text.lower():
    if i =='o':
        count = count +1
print(count)
# Out:
# 2

# %%
count = 0
for l in "Hello World":
    if l == 'o':
        count += 1
print(count, ' letters found')
# Out:
# 2  letters found

# %% [markdown]
# # String Membership Test

# %%
2 in [3,4,5,1]
# Out:
# False

# %%
print('l' in 'Hello World') #in operator to test membership
# Out:
# True

# %%
'ore' in 'Hello Worelde'
# Out:
# True

# %%
print('or' in 'Hello World')
# Out:
# True

# %% [markdown]
# # String Methods

# %% [markdown]
#     Some of the commonly used methods are lower(), upper(), join(), split(), find(), replace() etc

# %%
"Hello".lower()
# Out:
# 'hello'

# %%
"Hello".upper()
# Out:
# 'HELLO'

# %%
"This will split all words in a list".split()
# Out:
# ['This', 'will', 'split', 'all', 'words', 'in', 'a', 'list']

# %%
' '.join(['This', 'will', 'split', 'all', 'words', 'in', 'a', 'list'])
# Out:
# 'This will split all words in a list'

# %%
"Good Morning".find("orn")
# Out:
# 6

# %%
"#"*10
# Out:
# '##########'

# %%
len("213131232")*"#"
# Out:
# '#########'

# %%
prompt = "Here is my pan card details, help me to get the loan : PAN card number : 213131232"
prompt.replace("213131232","#"*len("213131232"))
# Out:
# 'Here is my pan card details, help me to get the loan : PAN card number : #########'

# %%
s1 = "Bad morning"

s2 = s1.replace("Bad", "######")

print(s1)
print(s2)
# Out:
# Bad morning
# ###### morning

# %% [markdown]
# # Python Program to Check where a String is Palindrome or not ?

# %%
myStr = "Madam"

#convert entire string to either lower or upper
myStr = myStr.lower()

#reverse string
revStr = reversed(myStr)


#check if the string is equal to its reverse
if list(myStr) == list(revStr):
    print("Given String is palindrome")
else:
    print("Given String is not palindrome")
# Out:
# Given String is palindrome

# %%
revStr = reversed(myStr)
list(revStr)
# Out:
# ['m', 'a', 'd', 'a', 'm']

# %% [markdown]
# # Python Program to Sort Words in Alphabetic Order?

# %%
text = "2 3 5 9 4"
words = text.split()
# words.sort()
words.sort()

# %%
words
# Out:
# ['2', '3', '4', '5', '9']

# %%
myStr = "12 2 python Program to Sort words in Alphabetic Order"

#breakdown the string into list of words
words = myStr.split()
words.sort()

for i in words:
    print(i)
# Out:
# 12
# 2
# Alphabetic
# Order
# Program
# Sort
# in
# python
# to
# words

# %%
words
# Out:
# ['Alphabetic', 'Order', 'Program', 'Sort', 'in', 'python', 'to', 'words']

# %%
myStr = "python Program to Sort words in Alphabetic Order"

#breakdown the string into list of words
words = myStr.split()

#sort the list
words.sort()

#print Sorted words are
for word in words:
    print(word)
# Out:
# Alphabetic
# Order
# Program
# Sort
# in
# python
# to
# words
